# %% [markdown]
# ### matplotlib.pyplot.scatter （散点图）
# y与x的散点图，具有不同的标记大小和/或颜色。

# %% [raw]
# matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, hold=None, data=None, **kwargs)

# %% [markdown]
# 参数：
#
# *** x, y :  ***
#     - 形状为(n, )的数组
#     - 表示数据的位置.
#
# *** s : ***
#     - 标量或形状为（n，）的数组，可选
#     - 标记点的大小，size in points**2. Default is rcParams['lines.markersize'] ** 2
#
# *** c： ***
#     - 颜色，序列或颜色序列，可选，默认：'b'
#     - 标记颜色。
#     - 可能的值：
#         * 单色格式字符串
#         * 一系列长度为n的颜色序列。
#         * 使用cmap和norm映射到n个数字序列的颜色。
#         * 一个二维数组，其中行是RGB或RGBA。
#
# > 请注意，c不应该是单个数字RGB或RGBA序列，因为它与要进行颜色映射的值数组无法区分。如果要为所有点指定相同的RGB或RGBA值，请使用具有单行的二维数组。
#
# *** marker：MarkerStyle，可选，默认值：'o'  ***
#     - 标记样式。 marker可以是类的实例，也可以是特定标记的文本缩写。
# > 请 [参阅标记](https://matplotlib.org/api/markers_api.html#module-matplotlib.markers) 以获取更多信息标记样式
#
# *** cmap：Colormap，可选，默认值：无  ***
#     - Colormap实例或注册的colormap名称。仅当c是浮点数组时才使用cmap。如果为None，则默认为rc image.cmap。
#
# *** norm : Normalize，可选，默认：无 ***
#     - Normalize实例用于将亮度数据缩放为0,1。仅当c是浮点数组时才使用norm。如果为None，请使用默认colors.Normalize。
#
# *** vmin, vmax : scalar, optional, default: None ***
#     - vmin和vmax与 norm 结合使用以归一化处理数据。如果为None，则使用颜色数组的相应最小值和最大值。如果传递一个规范实例，则忽略vmin和vmax。
#
# *** alpha：标量，可选，默认值：无 ***
#     - alpha混合值，介于0（透明）和1（不透明）之间。

# %% [markdown]
# ## Example

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# Fixing random state for reproducibility
np.random.seed(19680801)


x = np.arange(0.0, 50.0, 2.0)
y = x ** 1.3 + np.random.rand(*x.shape) * 30.0 # 使用了*号表达式
s = np.random.rand(*x.shape) * 800 + 500

plt.scatter(x, y, s, c="g", alpha=0.5, marker=r'$\clubsuit$', # '$ ... $'使用mathtext渲染字符串
            label="Luck")
plt.xlabel("Leprechauns")
plt.ylabel("Gold")
plt.legend(loc=2) #
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
c = np.sqrt(area)
r = np.sqrt(x * x + y * y)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# 显示区域之间的边界:
theta = np.arange(0, np.pi / 2, 0.01)
plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))

plt.show()

# %%
# 此样例绘制了一个简单的散点图
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 半径在0-15之间

print("area = ",area,"area.shape",area.shape)

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()
# Out:
# area =  [6.95642588e+02 7.28065984e+02 3.86071596e+00 1.09732098e+02
#  2.10645990e+02 5.15781732e+02 2.90121918e+00 4.72019572e+01
#  3.56383024e+02 7.50790417e+01 8.91407983e+02 1.57328131e+02
#  8.73379951e+02 5.23194081e+02 2.77470908e+00 9.08415917e+01
#  8.42907189e+02 3.21830151e+00 5.78495617e-02 3.07202603e+02
#  3.80875230e+02 5.92819929e+02 1.70255255e+02 4.50388287e+02
#  3.07560235e+02 4.51260371e+02 5.54151788e+01 2.13511128e+02
#  3.63158734e+01 4.54384353e+02 3.57876788e+02 8.39503324e+02
#  3.91684529e+02 6.54886228e+02 2.06430060e+02 8.01230404e+02
#  2.20486129e+02 8.37226448e+02 1.66697944e+02 3.64774135e+01
#  2.60153906e+02 1.44302430e+02 4.76724507e+01 1.07122811e+02
#  1.01311546e+02 6.28094850e+01 5.43229836e+02 5.66559836e+02
#  7.08456362e+02 1.15921790e+01] area.shape (50,)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2 + y**2)

plt.subplot(321)
plt.scatter(x, y, s=80, c=z, marker=">")

plt.subplot(322)
plt.scatter(x, y, s=80, c=z, marker=(5, 0))

verts = np.array([[-1, -1], [1, -1], [1, 1], [-1, -1]])
plt.subplot(323)
plt.scatter(x, y, s=80, c=z, marker=(verts, 0))
# equivalent:
# plt.scatter(x, y, s=80, c=z, marker=None, verts=verts)

plt.subplot(324)
plt.scatter(x, y, s=80, c=z, marker=(5, 1))

plt.subplot(325)
plt.scatter(x, y, s=80, c=z, marker='+')

plt.subplot(326)
plt.scatter(x, y, s=80, c=z, marker=(5, 2))

plt.show()
